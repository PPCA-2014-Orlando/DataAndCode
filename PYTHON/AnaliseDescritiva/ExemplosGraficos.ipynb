# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from pandas.tools.plotting import scatter_matrix

import matplotlib.pyplot as plt

import matplotlib
matplotlib.style.use('ggplot')



# %matplotlib inline

# %%
# First we will load the mtcars dataset and do a scatterplot matrix

mtcars = sm.datasets.get_rdataset('mtcars')
df = pd.DataFrame(mtcars.data)
scatter_matrix(df[[0,2,3,4,5]], alpha=0.3, figsize=(8, 8), diagonal='kde', marker='o');

# %%
# Next we will do the 3D mesh

xgv = np.arange(-1.5, 1.5, 0.1)
ygv = np.arange(-3, 3, 0.1)
[X,Y] = np.meshgrid(xgv, ygv)
V = np.exp(-(X**2 + Y**2))

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, V, rstride=1, cstride=1, cmap=plt.cm.jet, linewidth=0.25)
plt.title('Gridded Data Set');

# %%
# %whos
# Out:
# Variable         Type             Data/Info
# -------------------------------------------
# Axes3D           type             <class 'mpl_toolkits.mplot3d.axes3d.Axes3D'>
# V                ndarray          60Lx30L: 1800 elems, type `float64`, 14400 bytes
# X                ndarray          60Lx30L: 1800 elems, type `float64`, 14400 bytes
# Y                ndarray          60Lx30L: 1800 elems, type `float64`, 14400 bytes
# ax               Axes3DSubplot    Axes(0.125,0.125;0.775x0.775)
# df               DataFrame                              mpg<...>lvo 142E              2
# fig              Figure           Figure(800x480)
# matplotlib       module           <module 'matplotlib' from<...>matplotlib\__init__.pyc'>
# mtcars           Dataset          <class 'statsmodels.datasets.utils.Dataset'>
# np               module           <module 'numpy' from 'C:\<...>ages\numpy\__init__.pyc'>
# pd               module           <module 'pandas' from 'C:<...>ges\pandas\__init__.pyc'>
# plt              module           <module 'matplotlib.pyplo<...>s\matplotlib\pyplot.pyc'>
# scatter_matrix   function         <function scatter_matrix at 0x000000000A429A58>
# sm               module           <module 'statsmodels.api'<...>ages\statsmodels\api.py'>
# varname          int              123
# xgv              ndarray          30L: 30 elems, type `float64`, 240 bytes
# ygv              ndarray          60L: 60 elems, type `float64`, 480 bytes
