# %% [markdown]
# # Realizar a análise da qualidade dos registros de logs
#
# ## Importar os pacotes necessários

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Carregar os dados

# %%
dadoslogs = pd.read_csv('D:\\RepositoriosGitHub\\DataAndCode\\DADOS\\arquivodelogsmineracaoprocessos.csv' , \
                        header=0, quotechar='"', sep=';', encoding='utf-8',parse_dates=True)

# %% [markdown]
# ## Avaliar os conteúdo de cada colunas

# %%
dadoslogs.head(1)
# Out:
#    ideventolog                       nomefluxo eventosituacaosolicitacao  \
# 0        37199  SOLICITACAOSERVICOCOMQUALIDADE                REGISTRADA
#
#   situacaofinalsolicitacao  idsolicitacao  agrupamento atividade  \
# 0                  FECHADA           3031        31760  ABERTURA
#
#   transicaoatividade areaexecucaoatividade papelexecucaoatividade  \
# 0           complete                PORTAL                     --
#
#             ...              datahoraeventolog gruposervico       servico  \
# 0           ...            01-10-2014 07:32:00   APLICAÇÕES  PONTO DA SOF
#
#                operacaoservico tiposolicitacao prioridade  origemsolicitacao  \
# 0  DIAGNOSTICAR ERROS E FALHAS       INCIDENTE          3           2º NÍVEL
#
#   tempoatendimentoslaservico  tempoatendimentoslachamado  \
# 0                         18                           8
#
#    arearesponsavelservico
# 0            CIT-SISTEMAS
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Verificar os tipos de dados

# %%
dadoslogs.dtypes
# Out:
# ideventolog                       int64
# nomefluxo                        object
# eventosituacaosolicitacao        object
# situacaofinalsolicitacao         object
# idsolicitacao                     int64
# agrupamento                       int64
# atividade                        object
# transicaoatividade               object
# areaexecucaoatividade            object
# papelexecucaoatividade           object
# nomerecursoexecucaoatividade     object
# datahoraeventolog                object
# gruposervico                     object
# servico                          object
# operacaoservico                  object
# tiposolicitacao                  object
# prioridade                        int64
# origemsolicitacao                object
# tempoatendimentoslaservico      float64
# tempoatendimentoslachamado      float64
# arearesponsavelservico           object
# dtype: object

# %% [markdown]
# ## Converter tipos de dados

# %%
dadoslogs['datahoraeventolog'] = pd.to_datetime(dadoslogs['datahoraeventolog'], format="%d-%m-%Y %H:%M:%S")
dadoslogs['atividade'] = dadoslogs['atividade'].astype('category')
dadoslogs['transicaoatividade'] = dadoslogs['transicaoatividade'].astype('category')
dadoslogs['areaexecucaoatividade'] = dadoslogs['areaexecucaoatividade'].astype('category')
dadoslogs['gruposervico'] = dadoslogs['gruposervico'].astype('category')
dadoslogs['servico'] = dadoslogs['servico'].astype('category')
dadoslogs['tiposolicitacao'] = dadoslogs['tiposolicitacao'].astype('category')
dadoslogs['nomefluxo'] = dadoslogs['nomefluxo'].astype('category')
dadoslogs['eventosituacaosolicitacao'] = dadoslogs['eventosituacaosolicitacao'].astype('category')
dadoslogs['situacaofinalsolicitacao'] = dadoslogs['situacaofinalsolicitacao'].astype('category')
dadoslogs['operacaoservico'] = dadoslogs['operacaoservico'].astype('category')
dadoslogs['origemsolicitacao'] = dadoslogs['origemsolicitacao'].astype('category')
dadoslogs['arearesponsavelservico'] = dadoslogs['arearesponsavelservico'].astype('category')

# %%
dadoslogs.dtypes
# Out:
# ideventolog                              int64
# nomefluxo                             category
# eventosituacaosolicitacao             category
# situacaofinalsolicitacao              category
# idsolicitacao                            int64
# agrupamento                              int64
# atividade                             category
# transicaoatividade                    category
# areaexecucaoatividade                 category
# papelexecucaoatividade                  object
# nomerecursoexecucaoatividade            object
# datahoraeventolog               datetime64[ns]
# gruposervico                          category
# servico                               category
# operacaoservico                       category
# tiposolicitacao                       category
# prioridade                               int64
# origemsolicitacao                     category
# tempoatendimentoslaservico             float64
# tempoatendimentoslachamado             float64
# arearesponsavelservico                category
# dtype: object

# %% [markdown]
# ## Verificar volumes de registros

# %%
dadoslogs.size
# Out:
# 4423650

# %%
dadoslogs.tiposolicitacao.describe()
# Out:
# count         210650
# unique             2
# top       REQUISIÇÃO
# freq          200255
# Name: tiposolicitacao, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('tiposolicitacao')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# tiposolicitacao
# REQUISIÇÃO    200255
# INCIDENTE      10395
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
               kind='bar',legend=None,title="Quantidade de registros")
grafico.set_xlabel("tiposolicitacao")
grafico.set_ylabel("registros")

# %%
dadoslogs.situacaofinalsolicitacao.describe()
# Out:
# count      210650
# unique          6
# top       FECHADA
# freq       199416
# Name: situacaofinalsolicitacao, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('situacaofinalsolicitacao')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# situacaofinalsolicitacao
# FECHADA        199416
# CANCELADA        7432
# EMANDAMENTO      2493
# SUSPENSA          692
# RESOLVIDA         537
# REABERTA           80
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
           kind='bar',legend=None,title="Quantidade de registros")
grafico.set_xlabel("situacaosolicitacao")
grafico.set_ylabel("registros")

# %%
dadoslogs.atividade.describe()
# Out:
# count             210650
# unique                 8
# top       FILA DE ESPERA
# freq               76312
# Name: atividade, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('atividade')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# atividade
# FILA DE ESPERA     76312
# ATENDIMENTO        65272
# FECHAMENTO         30910
# ABERTURA           15657
# ENCERRAMENTO       14699
# RECLASSIFICAÇÃO     6943
# CANCELAMENTO         682
# REABERTURA           175
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
             kind='bar',legend=None,title="Quantidade de registros")
grafico.set_xlabel("atividade")
grafico.set_ylabel("registros")

# %%
dadoslogs.transicaoatividade.describe()
# Out:
# count       210650
# unique           4
# top       complete
# freq        121609
# Name: transicaoatividade, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('transicaoatividade')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# transicaoatividade
# complete    121609
# start        83453
# suspend       2845
# resume        2743
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
         kind='bar',legend=None,title="Quantidade de registros")
grafico.set_xlabel("transicaoatividade")
grafico.set_ylabel("registros")

# %%
dadoslogs.areaexecucaoatividade.describe()
# Out:
# count         210650
# unique            16
# top       CIT-NIVEL1
# freq          101597
# Name: areaexecucaoatividade, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('areaexecucaoatividade')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# areaexecucaoatividade
# CIT-NIVEL1        101597
# CIT-PRES-DF        30066
# DTI-SUPORTE        29555
# CIT-SISTEMAS       18992
# CIT-INFRA           7741
# PORTAL              5838
# DTI-INFRA           4908
# HPRINT              4737
# DTI-ELETR/REDE      1498
# DTI-SEGURANÇA       1482
# SISTEMA-SEI         1363
# SERPRO              1297
# RCS-TECNOLOGIA       703
# OUTROS               659
# DTI-CGSIS            159
# CIT-VIDEOCONF         55
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
          kind='bar',legend=None,title="Quantidade de registros")
grafico.set_xlabel("areaexecucaoatividade")
grafico.set_ylabel("registros")

# %%
dadoslogs.gruposervico.describe()
# Out:
# count      210650
# unique         13
# top       SUPORTE
# freq        83081
# Name: gruposervico, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('gruposervico')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# gruposervico
# SUPORTE                     83081
# APLICAÇÕES                  46227
# E-MAIL                      23581
# REDES                       23511
# ARMAZENAMENTO DE DADOS      14485
# SERVIDORES                   7299
# SEGURANÇA                    4327
# ENGENHARIA                   4118
# VIDEO CONFERENCIA            1347
# INFRAESTRUTURA               1254
# GERÊNCIA DE CONFIGURAÇÃO      946
# A.CLASSIFICAR                 274
# AMBIENTE COLABORATIVO         200
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
          kind='bar',legend=None,title="Quantidade de registros")
grafico.set_xlabel("gruposervico")
grafico.set_ylabel("registros")

# %%
dadoslogs.servico.describe()
# Out:
# count                                      210376
# unique                                        101
# top       SEI (SISTEMA ELETRÔNICO DE INFORMAÇÕES)
# freq                                        34154
# Name: servico, dtype: object

# %%
dadoslogs_group = dadoslogs.groupby('servico')
dadosvolume = dadoslogs_group.size().sort_values(ascending=False)
dadosvolume
# Out:
# servico
# SEI (SISTEMA ELETRÔNICO DE INFORMAÇÕES)    34154
# ESTAÇÃO DE TRABALHO                        30732
# EXPRESSO V3                                23571
# SOFTWARE                                   15827
# IMPRESSORA AMC                             15012
# SERVIDOR DE ARQUIVOS (PDCMP)               13917
# CONTROLE DE ACESSO                         12054
# OUTROS                                      7592
# IMPRESSORA                                  7197
# DHCP                                        6505
# SERVIDOR FÍSICO                             5748
# SCANNER                                     5552
# PONTOS DE REDE LÓGICA CABEADA               2979
# PONTO DA SOF                                2781
# PONTO DE REDE                               1736
# TOKEN (CERTIFICADO DIGITAL)                 1512
# INTERNET                                    1490
# CITSMART                                    1357
# REDE SEM FIO                                1312
# PONTO                                       1270
# MONITORAMENTO                               1254
# SIGAP                                       1128
# CADREDE                                     1081
# PONTOS DE REDE ELÉTRICA ESTABILIZADA        1041
# DOMINIO                                     1008
# ANTIVIRUS                                    988
# NOTEBOOK                                     942
# REDMINE                                      681
# VIRTUALIZACAO                                650
# SWITCH                                       631
#                                            ...
# E-PEDIDOS                                     44
# CIDI                                          44
# SARH                                          43
# NADA CONSTA                                   40
# SERVIÇOS GERAIS                               40
# SIOP                                          39
# CADIN                                         33
# ICS                                           32
# STORAGE                                       30
# SIGOV                                         30
# GCG                                           28
# ATESTE                                        28
# COMPRASNET                                    28
# SCDP                                          26
# ROTEAMENTO                                    22
# UPDATESITE                                    22
# MULTI-PONTO                                   19
# SISPAC                                        19
# WEB CONFERÊNCIA                               17
# SDSIC                                         17
# CREDOC                                        15
# PORTAL DE SERVICOS DA SPU                     15
# SIAPEDW                                       15
# SIEST                                         15
# SIGS                                          15
# ABRASIL                                       14
# SSD/DW                                        12
# PERGAMUM-MP                                   10
# SIAPESAÚDE                                    10
# SICONVDW                                      10
# dtype: int64

# %%
grafico = dadosvolume.sort_values(ascending=False).plot(\
          kind='barh',legend=None,title="Quantidade de registros", figsize=(12, 18))
grafico.set_xlabel("servico")
grafico.set_ylabel("registros")

# %%
dadoslogs_group = pd.groupby(dadoslogs,\
                             by=[dadoslogs.datahoraeventolog.dt.year,\
                                 dadoslogs.datahoraeventolog.dt.month])
dadosvolume = dadoslogs_group.size()
dadosvolume
# Out:
# datahoraeventolog  datahoraeventolog
# 2014               10                   22853
#                    11                   25354
#                    12                   21742
# 2015               1                    34297
#                    2                    51150
#                    3                    54798
#                    4                      456
# dtype: int64

# %%
grafico = dadosvolume.plot(kind='bar',\
          legend=None,title="Quantidade de registros")
grafico.set_xlabel("periodo")
grafico.set_ylabel("registros")
